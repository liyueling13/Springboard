# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
matches = pd.read_csv('eplmatches.csv')
matches.head()
# Out:
#    Season_End_Year  Wk        Date            Home  HomeGoals  AwayGoals  \
# 0             1993   1  1992-08-15   Coventry City          2          1
# 1             1993   1  1992-08-15    Leeds United          2          1
# 2             1993   1  1992-08-15   Sheffield Utd          2          1
# 3             1993   1  1992-08-15  Crystal Palace          3          3
# 4             1993   1  1992-08-15         Arsenal          2          4
#
#              Away FTR
# 0   Middlesbrough   H
# 1       Wimbledon   H
# 2  Manchester Utd   H
# 3       Blackburn   D
# 4    Norwich City   A

# %%
matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11646 entries, 0 to 11645
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Season_End_Year  11646 non-null  int64
#  1   Wk               11646 non-null  int64
#  2   Date             11646 non-null  object
#  3   Home             11646 non-null  object
#  4   HomeGoals        11646 non-null  int64
#  5   AwayGoals        11646 non-null  int64
#  6   Away             11646 non-null  object
#  7   FTR              11646 non-null  object
# dtypes: int64(4), object(4)
# memory usage: 728.0+ KB

# %%
matches['Date'] = pd.to_datetime(matches['Date'])

# %%
matches['Home'].value_counts()
# Out:
# Arsenal            576
# Liverpool          576
# Manchester Utd     576
# Chelsea            576
# Everton            576
# Tottenham          576
# Aston Villa        519
# Newcastle Utd      517
# West Ham           498
# Manchester City    481
# Southampton        443
# Blackburn          348
# Leicester City     306
# Sunderland         304
# Middlesbrough      287
# Fulham             285
# Leeds United       272
# Crystal Palace     251
# Bolton             247
# West Brom          247
# Norwich City       196
# Stoke City         190
# Coventry City      177
# Sheffield Weds     158
# Wimbledon          158
# Wigan Athletic     152
# Burnley            152
# Charlton Ath       152
# Wolves             152
# Watford            152
# QPR                139
# Portsmouth         133
# Derby County       133
# Birmingham City    133
# Swansea City       133
# Ipswich Town       101
# Sheffield Utd       99
# Nott'ham Forest     99
# Hull City           95
# Brighton            95
# ...

# %%
villans_home = matches.loc[(matches['Home']=='Aston Villa')]
villans_away = matches.loc[(matches['Away']=='Aston Villa')]

# %%
villans_home_1992 = matches.loc[(matches['Season_End_Year']==1993)]
villans_away_1992 = matches.loc[(matches['Season_End_Year']==1993)]

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=villans_home_1992, x='Date', y='HomeGoals', hue='FTR', ci=None)
plt.show()
